# %% [markdown]
# # Ling 450/807 SFU - Assignment 1
#
# Virginia Uhi, Eunice Wong, & Han Zhang

# %% [markdown]
# ## Import packages
#
# We import everything we will need here at the beginning and load the spaCy language model. Note that we are using the small English model. One thing you could try is to download and load [other models for English](https://spacy.io/models/en) and compare the results.

# %%
# Importing Spacy 
import spacy
import re
from spacy.matcher import Matcher
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)

# %% [markdown]
# ## Approach 1: Using regular expressions

# %%
# this loads and processes only one file at a time. You need to do 5 and comment on the results
# to load the 5 texts, you can just change the name of the file below or figure out a way 
# to pass a list of files to the read command. It's up to you

with open ("A1_data/5c1dbe1d1e67d78e2797d611.txt", "r", encoding='utf-8') as f:
    text = f.read()

# %%
# The starter file loads and processes only one file at a time. We are using the command to do 5 files at the same time

# First we take five text files out 

five_files = ["A1_data/5c1548a31e67d78e2771624f.txt", "A1_data/5c489df91e67d78e271d66c5.txt", "A1_data/5c182ac21e67d78e277944ad.txt", "A1_data/5c28972a795bd2fac69fa974.txt", "A1_data/5c29beda1e67d78e27b74939.txt"]

# Process five text files at the same time, and have all the quotes in the five files can be extracted and put in the same file
with open ("Regular_Expression_All.txt", 'w', encoding = "utf-8") as output:
    def get_quotes(text):
        quotes = re.findall(r'["“](.*?)[”"]', text) 
            # so that every time as soon as Spacy identify any quotation marks (either straight or curly), the quoted content with the quotation mark will be extracted
        return(quotes)
    
    for file_path in five_files: 
        output.write(file_path + "\n")
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
                # The starter code seperate the text into sentences at the begining; However, for the sake of better identifying the sentence, we decide to not seperate the sentences first

            found_quotes = get_quotes(text) 
            print(found_quotes)
            for quote in found_quotes:
                output.write(str(quote) + "\n")  # Using the "\n" to make the quotes listed line by line
# Out:
# ['Some of those ‘soft’ skills are in short supply, but they’re what employers are looking for,', 'There’s a societal cost to having someone remain unemployed,', 'There are health-care costs. There are welfare costs. There can be criminal justice costs,', 'road map', 'should move to skills-based hiring,', 'practices that prioritize … credentials and experience.', 'These are things that are the least susceptible to technological disruption,']
# ["It's good that we take the time early on to completely shut hockey off and just relax and then the closer we get to coming back, we've got to get the minds ready,", "Most guys were here last year and we learned a lesson from last year when we weren't as good after the break. We know what to do this time and what not to.", 'He enabled us to at least hang in there and get a point out of this game,', 'The positive is you came in here against one of the best teams and in my opinion, we could have had that game.', "I don't think we played our best game, but again, we found a way to win and I think that's a big key,", "That was one of our weaknesses last year. We couldn't find ways to win and this year, it's the opposite. Good teams, they find ways to win.", "Going into the break it's important to go in with a good taste in your mouth,", "We played the best when the game was on the line in the third and I thought we had some great looks that made Mrazek make some big saves for them. ... We'll take the two points heading into the break and we'll come back refreshed and ready to go."]
# ["As a young person, I've experienced that fear and distrust. Just seeing police officers, I feel like I can be also racially targeted,", "To avoid any cases like that in the future, it's important to come together and to strategize and to be honest,", "What gives me hope is the level of commitment that our police chief has to working alongside FSIN youth because there hasn't been a relationship historically between the FSIN youth representatives and Saskatoon city police,", 'I thought this was a good time to write a letter to the Saskatoon city police on questioning [if they are] going to be taking body cameras on,', "And if so, could they kind of explain to FSIN youth what it's gonna look like and what the timeline is.", 'very committed', 'life-changing and heartbreaking,', "I can honestly say that it's very emotional to listen to stories of the kind of suffering that goes on in the Indigenous community due to being impoverished, due to violence and due to racism,", "The treatment of Indigenous peoples in this country, it's heartbreaking but I can also say that it provides me hope as well when I talk to young people and I see that they persevere.", "It may not look perfect to other people, but I can say that I've always been authentically myself I would want all young people to do the same,", 'I would say there definitely is pressure, but I try to be as gentle and understanding with myself as I would expect to how I should treat another young person.', 'As young people we understand that this land is foundational to who we are,']
# ['I’m so excited and I am so honoured to be selected by you here,', 'My eyes are full of tears because I love this land so deeply,', 'He’s not from our local community. He cannot represent you, represent us,', 'I believe we will have a good chance to win in Burnaby South as I believe right now I’m very familiar with our community. I’m one of the people here.', 'elected', 'Essentially, the leader will choose the candidate in each byelection,', 'whole country']
# ['The Australian Government is concerned about the recent detention of two Canadian citizens in China,', 'We would be very concerned if these cases were related to legal proceedings currently underway in Canada involving a Chinese citizen, Ms. Meng Wanzhou.', 'basically kidnapping', 'every confidence in the fairness and independence of Canada’s administration of justice.', 'We are deeply concerned about the recent detentions of Canadian citizens Michael Kovrig and Michael Spavor in the People’s Republic of China. We ask the Australian Government without further delay to support Canada’s call for the immediate release of these two detainees,', 'deep concern', 'We share Canada’s commitment to the rule of law as fundamental to all free societies, and we will defend and uphold this principle,', 'the declared motive for their investigation raises concerns about legitimate research and business practices in China.', 'The denial of access to a lawyer under their status of detention is contrary to the right of defence. The EU fully supports the efforts of the Canadian Government on this matter.']

# %% [markdown]
# ## Approach 2: Using spaCy's Matcher

# %% [markdown]
# This approach is based on notebooks by [William J.B. Mattingly](https://wjbmattingly.com/). His book, Introduction to Python for Humanists, is available online from the [SFU Library](https://sfu-primo.hosted.exlibrisgroup.com/permalink/f/usv8m3/01SFUL_ALMA51476999620003611).
#
# For more on spaCy's Matcher, see Advanced NLP with spaCy, [chapter 2](https://course.spacy.io/en/chapter2)).
#
# We have already loaded everything we need at the beginning of this notebook (imported Matcher, assigned it to a `matcher` object), so now we can use it.

# %% [markdown]
# ## Finding quotes and speakers

# %%
# convert it to a spacy doc
doc = nlp(text)

# %% [markdown]
# ### Finding proper nouns

# %%
# This is optional. It just tells you who are the people mentioned. You can use it later if you want to find out the speakers of the quotes

matcher = Matcher(nlp.vocab)
pattern_n = [{"POS": "PROPN"}]
matcher.add("PROPER_NOUNS", [pattern_n], greedy="LONGEST")
doc = nlp(text)
matches = matcher(doc)
print (len(matches))
for match in matches[:10]:
    print (match, doc[match[1]:match[2]])
    
## You can try to extract full names by adding multi-word nouns, http://spacy.pythonhumanities.com/02_02_matcher.html
# Out:
# 63
# (3232560085755078826, 1, 2) CTV
# (3232560085755078826, 2, 3) Vancouver
# (3232560085755078826, 6, 7) Abbotsford
# (3232560085755078826, 8, 9) B.C.
# (3232560085755078826, 25, 26) Africa
# (3232560085755078826, 42, 43) Kim
# (3232560085755078826, 44, 45) Clark
# (3232560085755078826, 45, 46) Moran
# (3232560085755078826, 52, 53) Immigration
# (3232560085755078826, 54, 55) Refugees

# %% [markdown]
# ### Finding quotes

# %%
import os

for file in os.listdir("A1_data"): 
    print(file)

    with open ("A1_data/"+file, "r", encoding='utf-8') as f: #open all files in the folder and read them
        text = f.read()

    matcher = Matcher(nlp.vocab)
    
    pattern_q16 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #7
    pattern_q17 = [{'ORTH': '“'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '”'}] #4
    # both curly and straight quotes
    
    matcher.add("QUOTES", [pattern_q16, pattern_q17])
    doc = nlp(text)
    matches_q = matcher(doc)
    print(len(matches_q))
    for match in matches_q[:10]:
        print(match, doc[match[1]:match[2]])
    print("\n") #blank space between outputs
# Out:
# 5c33859e1e67d78e27d12893.txt
# 12
# (16432004385153140588, 622, 636) "That certainly bears out in our experience here in the morgue."
# (16432004385153140588, 845, 850) "black box warning"
# (16432004385153140588, 1603, 1607) "nerve pills"
# (16432004385153140588, 1635, 1640) " says LeBlanc. "
# (16432004385153140588, 2124, 2128) "fumbled into"
# (16432004385153140588, 2244, 2248) "acutely aware"
# (16432004385153140588, 2247, 2260) " of what can happen when benzodiazepines are combined with opioids. "
# (16432004385153140588, 2244, 2260) "acutely aware" of what can happen when benzodiazepines are combined with opioids. "
# (16432004385153140588, 2585, 2590) "another druggie."
# (16432004385153140588, 2746, 2751) " Golden says. "
#
#
# 5c5404491e67d78e274131a2.txt
# 0
#
#
# 5c4962f31e67d78e271f9498.txt
# 22
# (16432004385153140588, 25, 34) “A spirit that will not die.”
# (16432004385153140588, 138, 144) “Make American Great Again”
# (16432004385153140588, 199, 222) “People saw the original video and took an early side, and they are just not budging from that side,”
# (16432004385153140588, 299, 309) “I stand with Covington Catholic High School.”
# (16432004385153140588, 380, 397) “I witnessed people from Covington Catholic saying homophobic slurs, some saying racist things,”
# (16432004385153140588, 401, 419) “They would say misogynistic comments, and it was just accepted within the culture there.”
# (16432004385153140588, 506, 512) “Build that wall!”
# (16432004385153140588, 513, 521) “Go back to the reservation!”
# (16432004385153140588, 598, 604) “far-left activists”
# (16432004385153140588, 615, 656) “Far-left activists and members of the national and state media isolated a very few seconds of video footage from any shred of context and many decided it was time to attack and denigrate these young people,”
#
#
# 5c32f9841e67d78e27cfa4eb.txt
# 0
#
#
# 5c3370aa1e67d78e27d0f869.txt
# 0
#
#
# 5c32e5141e67d78e27cf6aeb.txt
# 0
#
#
# 5c5da7aa1e67d78e275f8a3c.txt
# 0
#
#
# 5c5d3e251e67d78e275e54b5.txt
# 14
# (16432004385153140588, 70, 99) “Neither the current nor the previous attorney general was ever directed by me or by anyone in my office to take a decision in this matter,”
# (16432004385153140588, 124, 148) “The prime minister must immediately come clean to Canadians about what he knew about this case and when he knew it,”
# (16432004385153140588, 154, 164) “Nothing less than full disclosure is acceptable.”
# (16432004385153140588, 471, 503) “It is a pillar of our democracy that our system of justice be free from even the perception of political interference and uphold the highest levels of public confidence,”
# (16432004385153140588, 579, 592) “The allegations in the Globe story this morning are false,”
# (16432004385153140588, 626, 652) “At no time did I or my office direct the current or previous attorney general to make any particular decision in this matter,”
# (16432004385153140588, 677, 681) “under pressure”
# (16432004385153140588, 705, 734) “As the Prime Minister said earlier today, neither the Prime Minister nor his office put my predecessor or myself under pressure nor gave any directives,”
# (16432004385153140588, 870, 883) “The minister will not be commenting on this story today,”
# (16432004385153140588, 1025, 1032) “unreasonable exercise of her discretion”
#
#
# 5c146e42795bd2fcce2ea8e5.txt
# 5
# (16432004385153140588, 24, 28) “playing games”
# (16432004385153140588, 215, 225) “This has degenerated into an acrimonious fight,”
# (16432004385153140588, 288, 300) “have a further statement next week. Stay tuned!”
# (16432004385153140588, 702, 712) “tossing roadblocks in the way of democracy,”
# (16432004385153140588, 713, 722) “it would be sending the wrong message”
#
#
# 5c29ccfc1e67d78e27b76bfb.txt
# 5
# (16432004385153140588, 179, 194) "support the rationale for including family members in a veterans treatment plan."
# (16432004385153140588, 348, 373) "it must be made clear that the full range of benefits and services offers to veterans is NOT offered to family members."
# (16432004385153140588, 601, 629) "It is part of normal business processes to connect to different areas of the department to ensure that messaging accurately reflects department policy and activity,"
# (16432004385153140588, 972, 978) "large number of emails"
# (16432004385153140588, 1007, 1042) "It was difficult at the outset to understand how someone who suffers from PTSD as a result of a murder they committed should be eligible for health benefits from Veteran Affairs Canada,"
#
#
# 5c182ac21e67d78e277944ad.txt
# 4
# (16432004385153140588, 366, 370) "very committed"
# (16432004385153140588, 445, 453) "life-changing and heartbreaking,"
# (16432004385153140588, 596, 630) "I would say there definitely is pressure, but I try to be as gentle and understanding with myself as I would expect to how I should treat another young person."
# (16432004385153140588, 677, 694) "As young people we understand that this land is foundational to who we are,"
#
#
# 5c533fe21e67d78e273e92d1.txt
# 1
# (16432004385153140588, 593, 616) “The active front panel, interior material and internal drain provide ease in cleaning the interior of the dog house,”
#
#
# 5c483b26795bd2b724e92a68.txt
# 4
# (16432004385153140588, 222, 237) “We do know that sugary drinks have little to no health benefits,”
# (16432004385153140588, 240, 266) “This is a really great place to start to help to support our youth at putting their health first and making healthier choices.”
# (16432004385153140588, 408, 428) “This will provide public health advocates with a credible document to help influence change in their schools.”
# (16432004385153140588, 544, 552) “significant consequences on nutrient intakes.”
#
#
# 5c50a9ee1e67d78e27364c05.txt
# 0
#
#
# 5c49ef691e67d78e272197a5.txt
# 11
# (16432004385153140588, 172, 177) " Nedeljkovic said. "
# (16432004385153140588, 176, 190) "Just another Wednesday night game and we came out on top."
# (16432004385153140588, 172, 190) " Nedeljkovic said. "Just another Wednesday night game and we came out on top."
# (16432004385153140588, 424, 429) " he said. "
# (16432004385153140588, 515, 527) "They wanted these two points more than we did."
# (16432004385153140588, 794, 799) " McKegg said. "
# (16432004385153140588, 798, 808) "And it paid dividends in that period."
# (16432004385153140588, 794, 808) " McKegg said. "And it paid dividends in that period."
# (16432004385153140588, 974, 995) "We can take this as a fresh start and come back mentally tough and play that much better,"
# (16432004385153140588, 994, 999) " Horvat said. "
#
#
# 5c2aa6971e67d78e27b9ab24.txt
# 11
# (16432004385153140588, 693, 698) “difficult to understand”
# (16432004385153140588, 775, 800) “There were just so many gaps that one expert essentially said it was as though they were being purposely non-transparent,”
# (16432004385153140588, 1129, 1142) “keenly aware of the need to intervene in the economy.”
# (16432004385153140588, 1273, 1288) “This is not the right time in the cycle for deficit spending,”
# (16432004385153140588, 1633, 1638) “significant downward revisions”
# (16432004385153140588, 1648, 1656) “diminish the magnitude of economic gains”
# (16432004385153140588, 1782, 1786) “fiscal multipliers”
# (16432004385153140588, 2022, 2045) “My criticism of politicians is they tend to sell this stuff on stimulus grounds rather than production capacity growth grounds,”
# (16432004385153140588, 2233, 2238) “shovel-ready”
# (16432004385153140588, 2542, 2575) “Not only has the government failed to provide a business environment conducive to more investment by firms, it has not produced the promised boom in its own infrastructure spending,”
#
#
# 5c54662d1e67d78e27425afa.txt
# 4
# (16432004385153140588, 78, 82) "deeply concerned"
# (16432004385153140588, 182, 191) " he said, adding the potential cuts "
# (16432004385153140588, 547, 554) "shock and a disappointment,"
# (16432004385153140588, 567, 595) "We are also working with the unions and other potential investors and automakers to look at what a future could be for that particular plant,"
#
#
# 5c498cc6795bd264151080e0.txt
# 5
# (16432004385153140588, 270, 286) “You have to analyze, strategize and execute in a matter of seconds,”
# (16432004385153140588, 289, 297) “It plays to my strengths.”
# (16432004385153140588, 382, 394) “None of us are powerful because of our disabilities,”
# (16432004385153140588, 485, 494) “He carried most of the weight,”
# (16432004385153140588, 497, 505) “I was super-green.”
#
#
# 5c3f55241e67d78e27f63e5a.txt
# 0
#
#
# 5c53fcaf1e67d78e2740a25d.txt
# 0
#
#
# 5c49e1261e67d78e2721712b.txt
# 1
# (16432004385153140588, 401, 406) "enormous market potential"
#
#
# 5c541912795bd22bf37ca662.txt
# 4
# (16432004385153140588, 119, 134) “This is the kind of thing people have been predicting for years,”
# (16432004385153140588, 579, 599) “If the air is kind of moving apart, it allows surface air to rise more easily,”
# (16432004385153140588, 602, 617) “That helps a storm to work, storms depend on rising air.”
# (16432004385153140588, 770, 785) “Cities have to be planned to deal with that kind of thing.”
#
#
# 5c1e0b68795bd2a5d03a49a9.txt
# 1
# (16432004385153140588, 760, 771) “Why would I pander to the millionaires club?”
#
#
# 5c2858471e67d78e27b3b633.txt
# 6
# (16432004385153140588, 20, 24) “snow laps”
# (16432004385153140588, 42, 50) “The best sleigh this Christmas!”
# (16432004385153140588, 181, 195) “thorough, expansive process in searching for its new independent directors,”
# (16432004385153140588, 609, 617) “Forget about Ford and GM,”
# (16432004385153140588, 708, 718) “help people live longer, brighter lives.”
# (16432004385153140588, 813, 820) “package of remedies and relief”
#
#
# 5c1f08711e67d78e279bf66d.txt
# 9
# (16432004385153140588, 48, 52) "running around"
# (16432004385153140588, 80, 95) "We have several broken power lines in between Duncan and Lake Cowichan,"
# (16432004385153140588, 94, 102) " Peters said in an interview. "
# (16432004385153140588, 80, 102) "We have several broken power lines in between Duncan and Lake Cowichan," Peters said in an interview. "
# (16432004385153140588, 481, 502) "There are hundreds of individual outages that crews must attend to individually to make complicated and lengthy repairs,"
# (16432004385153140588, 506, 530) "For example, replacing a damaged power pole is considered a mini construction job and can take up to eight hours."
# (16432004385153140588, 857, 871) "The situation remains the same but we continue to make progress,"
# (16432004385153140588, 894, 898) "warming centre"
# (16432004385153140588, 904, 928) "Our volunteers are ready to welcome residents without power to Beban Park Social Lounge to warm up and charge their phones,"
#
#
# 5c5d3f0a1e67d78e275e5788.txt
# 0
#
#
# 5c29947f1e67d78e27b6d330.txt
# 18
# (16432004385153140588, 88, 96) "Are you wearing blue shoes?"
# (16432004385153140588, 199, 205) " Bardos blurted out. "
# (16432004385153140588, 345, 350) "the bomb."
# (16432004385153140588, 395, 400) " she said, "
# (16432004385153140588, 399, 407) "but I am a mutant."
# (16432004385153140588, 395, 407) " she said, "but I am a mutant."
# (16432004385153140588, 576, 580) "litmus test"
# (16432004385153140588, 1067, 1073) "sexual bucket list."
# (16432004385153140588, 1093, 1097) "cancer drama"
# (16432004385153140588, 1132, 1140) "I see you beyond cancer."
#
#
# 5c1548a31e67d78e2771624f.txt
# 4
# (16432004385153140588, 397, 401) “road map”
# (16432004385153140588, 413, 423) “should move to skills-based hiring,”
# (16432004385153140588, 426, 436) “practices that prioritize … credentials and experience.”
# (16432004385153140588, 628, 642) “These are things that are the least susceptible to technological disruption,”
#
#
# 5c47fce51e67d78e271b1f7a.txt
# 2
# (16432004385153140588, 183, 187) “outside eye”
# (16432004385153140588, 420, 431) “I always felt it deserved to be longer,”
#
#
# 5c3f78b21e67d78e27f6a477.txt
# 2
# (16432004385153140588, 446, 464) “We really did expect to have our license by now or to be darned close,”
# (16432004385153140588, 649, 674) “I think if they all got a beer together and they drank one in a room, they would figure it out,”
#
#
# 5c1dbe1d1e67d78e2797d611.txt
# 7
# (16432004385153140588, 108, 116) " Kim told CTV News Friday. "
# (16432004385153140588, 115, 133) "The fact that we are being accused right now of an unethical adoption is crazy."
# (16432004385153140588, 108, 133) " Kim told CTV News Friday. "The fact that we are being accused right now of an unethical adoption is crazy."
# (16432004385153140588, 164, 174) "It does say that in the letter,"
# (16432004385153140588, 173, 180) " Kim confirmed, adding that "
# (16432004385153140588, 179, 209) "I have no idea where that information came from because both Clark and I were there in the office with all of the workers from the orphanage."
# (16432004385153140588, 280, 309) "in some cases, extra steps in the citizenship or immigration process may be needed to make sure the adoption meets all requirements of international adoption."
#
#
# 5c1de1661e67d78e27984d34.txt
# 4
# (16432004385153140588, 417, 428) “will have a positive aspirational aspect to it.”
# (16432004385153140588, 496, 501) “illegal border crossers”
# (16432004385153140588, 980, 1010) “People who have those legitimate concerns deserve to be spoken to with respect and have their concerns taken into account, not brushed aside with insulting labels,”
# (16432004385153140588, 1025, 1034) “It really evokes a negative reaction.”
#
#
# 5c488fac1e67d78e271d405b.txt
# 0
#
#
# 5c149ffc1e67d78e276fbd44.txt
# 1
# (16432004385153140588, 514, 530) “This game is all about getting a certain percentage of people to respond,”
#
#
# 5c494e541e67d78e271f514e.txt
# 9
# (16432004385153140588, 11, 20) “The Kid Who Would Be King,”
# (16432004385153140588, 115, 123) “The Kid Who Would Be King”
# (16432004385153140588, 159, 168) "The Kid Who Would Be King."
# (16432004385153140588, 206, 215) "The Kid Who Would Be King."
# (16432004385153140588, 235, 244) "The Kid Who Would Be King."
# (16432004385153140588, 268, 277) "The Kid Who Would Be King."
# (16432004385153140588, 316, 322) “Attack the Block,”
# (16432004385153140588, 331, 336) “Star Wars’”
# (16432004385153140588, 718, 726) “The Kid Who Would Be King”
#
#
# 5c159cb81e67d78e277241fd.txt
# 11
# (16432004385153140588, 82, 88) "clear and indisputable pattern"
# (16432004385153140588, 127, 132) " Sinclair states. "
# (16432004385153140588, 131, 150) "The board has perpetuated systemic discrimination that has directly impacted First Nation peoples in Thunder Bay."
# (16432004385153140588, 127, 150) " Sinclair states. "The board has perpetuated systemic discrimination that has directly impacted First Nation peoples in Thunder Bay."
# (16432004385153140588, 335, 363) "It is unacceptable however that an administrator was so hastily selected without any consultation from the Indigenous community and the Thunder Bay community in general,"
# (16432004385153140588, 370, 403) "Policing in Thunder Bay presents unique challenges and realities and it is critical that the administrator is well versed in these issues and has an established rapport with Indigenous people."
# (16432004385153140588, 631, 653) "The issues identified with Thunder Bay policing through this investigation are not the result of behaviours by individual racists,"
# (16432004385153140588, 652, 657) " Sinclair writes. "
# (16432004385153140588, 631, 657) "The issues identified with Thunder Bay policing through this investigation are not the result of behaviours by individual racists," Sinclair writes. "
# (16432004385153140588, 656, 687) "They are indicative of a broader, deeper and more systemic level of discrimination in which an unacceptable status quo is viewed as the normal state of affairs."
#
#
# 5c29e8a8795bd2ac48ec6e58.txt
# 3
# (16432004385153140588, 405, 416) “We do not comment on mergers and acquisitions,”
# (16432004385153140588, 688, 711) “believed in the long-term value of these publications and in the importance of protecting quality journalism in Canada.”
# (16432004385153140588, 764, 777) “safeguards to ensure editorial independence from ownership and sales teams,”
#
#
# 5c52b36a1e67d78e273d029c.txt
# 2
# (16432004385153140588, 77, 81) “The Match”
# (16432004385153140588, 185, 193) “I have to be careful,”
#
#
# 5c1dccbf1e67d78e279807d8.txt
# 5
# (16432004385153140588, 224, 240) “If you want Marvel, you can go to another comic book shop.”
# (16432004385153140588, 485, 492) “Every publisher rejected me,”
# (16432004385153140588, 611, 628) “I wanted to emphasize that no matter who you are you can do anything.”
# (16432004385153140588, 687, 694) “Now I have tons.”
# (16432004385153140588, 1031, 1039) “You gotta start somewhere,”
#
#
# 5c5e50711e67d78e27616b23.txt
# 4
# (16432004385153140588, 61, 117) "My department has issued a Ministerial Order under the Railway Safety Act to all railway companies mandating the use of handbrakes should a train be stopped on a mountain grade after an emergency use of the air brakes. This order takes effect immediately and will remain in effect as long as necessary,"
# (16432004385153140588, 121, 149) "As I have said many times before, rail safety is my top priority and I will never hesitate to take appropriate actions when necessary."
# (16432004385153140588, 401, 409) "This is a major challenge."
# (16432004385153140588, 477, 504) "Our forefathers in the business would never have put a train together that big under those climatic conditions and expected it to run smoothly,"
#
#
# 5c5418cc795bd22bf37ca606.txt
# 2
# (16432004385153140588, 249, 267) “At least three of our BC Liberal MLAs have signalled they are not running again,”
# (16432004385153140588, 705, 709) “large number”
#
#
# 5c33e1a71e67d78e27d2193c.txt
# 3
# (16432004385153140588, 9, 14) “no mas.”
# (16432004385153140588, 369, 376) “They moan about “amateurs”
# (16432004385153140588, 622, 626) “Bird Man”
#
#
# 5c5490681e67d78e2742d421.txt
# 14
# (16432004385153140588, 271, 287) “Most of them hated that name because it meant they had no individuality,”
# (16432004385153140588, 358, 371) “You had no identity. You were just a George.”
# (16432004385153140588, 513, 523) “home for whiteness in the western hemisphere,”
# (16432004385153140588, 745, 754) “I never put these elements together,”
# (16432004385153140588, 997, 1014) “anyone belonging to any race deemed unsuited to the climate or requirements of Canada.”
# (16432004385153140588, 1319, 1328) “to keep Blacks in their place,”
# (16432004385153140588, 1331, 1349) “The very constitution of the conductors’ union indicated that membership had to be white,”
# (16432004385153140588, 1571, 1575) “too familiar”
# (16432004385153140588, 1585, 1612) “tended to accumulate the closer the porter got to the age of retirement, an obvious attempt by the company to avoid paying pensions.”
# (16432004385153140588, 1682, 1687) “sleepy car porters”
#
#
# 5c28eba91e67d78e27b54bca.txt
# 9
# (16432004385153140588, 219, 235) "Nothing was going to stop me from what I wanted to do tonight,"
# (16432004385153140588, 234, 239) " Nunes said. "
# (16432004385153140588, 219, 239) "Nothing was going to stop me from what I wanted to do tonight," Nunes said. "
# (16432004385153140588, 289, 302) "I knew this was happening, I told you all!"
# (16432004385153140588, 301, 306) " Nunes said. "
# (16432004385153140588, 455, 466) "It was always about being the champion again,"
# (16432004385153140588, 681, 686) "The Lioness."
# (16432004385153140588, 789, 803) "I know I hit hard, but sometimes you never know,"
# (16432004385153140588, 802, 807) " Nunes said. "
#
#
# 5c48278d1e67d78e271c1a28.txt
# 2
# (16432004385153140588, 692, 697) “a lot stronger”
# (16432004385153140588, 1108, 1124) “I get to build my schedule around that and not have the uncertainty,”
#
#
# 5c2955161e67d78e27b64992.txt
# 2
# (16432004385153140588, 929, 952) “Putin believes that if Russia gives in, the pressure will only grow and the sanctions will be expanded further,”
# (16432004385153140588, 1221, 1249) “Moving further along the same track would inevitably lead to the point where it would become more difficult to control the situation regarding nuclear weapons,”
#
#
# 5c3e27a31e67d78e27f27b38.txt
# 16
# (16432004385153140588, 198, 203) “short of breath”
# (16432004385153140588, 279, 285) “f--ked someone”
# (16432004385153140588, 290, 298) “plucked the blossom of a woman”
# (16432004385153140588, 361, 365) “super excited”
# (16432004385153140588, 504, 511) “from drowning in some bitches”
# (16432004385153140588, 799, 803) “open up”
# (16432004385153140588, 1099, 1105) “I … I …”
# (16432004385153140588, 1298, 1302) “the heck”
# (16432004385153140588, 1357, 1362) “Never Been Kissed”
# (16432004385153140588, 1392, 1396) “older girls”
#
#
# 5c2059ec1e67d78e279ea86c.txt
# 14
# (16432004385153140588, 378, 383) "our Canadian baby"
# (16432004385153140588, 452, 462) " hurled at her in a sharp tone by "
# (16432004385153140588, 450, 462) "refugee" hurled at her in a sharp tone by "
# (16432004385153140588, 461, 469) "men who hate Arab people."
# (16432004385153140588, 452, 469) " hurled at her in a sharp tone by "men who hate Arab people."
# (16432004385153140588, 563, 569) "routine social conversations,"
# (16432004385153140588, 568, 589) " and to discuss basic needs. She also requires a knowledge of a variety of simple grammatical structures, "
# (16432004385153140588, 588, 596) "along with some complex ones."
# (16432004385153140588, 1182, 1200) "When you have a family and children to look after, my study comes afterwards,"
# (16432004385153140588, 1269, 1277) "We can borrow the money,"
#
#
# 5c529d681e67d78e273c4cb9.txt
# 8
# (16432004385153140588, 301, 315) “If anything, our unity is stronger today than it was,”
# (16432004385153140588, 659, 669) “an uncanny way to be able to listen”
# (16432004385153140588, 680, 689) “eventually everybody can feel OK with.”
# (16432004385153140588, 850, 861) “knows the minds and hearts of his colleagues.”
# (16432004385153140588, 914, 938) “The issue that the president chose to battle on, he just picked an issue where every Democrat is completely unified,”
# (16432004385153140588, 941, 949) “Our caucus just welded together.”
# (16432004385153140588, 1121, 1126) “take the mantle”
# (16432004385153140588, 1203, 1215) “It reinforced a lot of our steadfastness and resolve,”
#
#
# 5c34d7211e67d78e27d54599.txt
# 2
# (16432004385153140588, 161, 168) "released in due course."
# (16432004385153140588, 271, 297) "Kim is eager to remind the Trump administration that he does have diplomatic and economic options besides what Washington and Seoul can offer,"
#
#
# 5c339b091e67d78e27d16414.txt
# 1
# (16432004385153140588, 634, 647) “use available resources to make educated decisions in choosing food.”
#
#
# 5c5314a91e67d78e273e13be.txt
# 5
# (16432004385153140588, 101, 116) "This is the kind of thing people have been predicting for years,"
# (16432004385153140588, 599, 619) "If the air is kind of moving apart, it allows surface air to rise more easily,"
# (16432004385153140588, 618, 623) " Atkinson said. "
# (16432004385153140588, 622, 637) "That helps a storm to work, storms depend on rising air."
# (16432004385153140588, 792, 807) "Cities have to be planned to deal with that kind of thing."
#
#
# 5c52c73b795bd245ab059d61.txt
# 6
# (16432004385153140588, 162, 176) “The figures suggest this industry is going in the wrong direction,”
# (16432004385153140588, 260, 271) “What we need most urgently is a deal,”
# (16432004385153140588, 733, 748) “extremely disappointed the threat of a hard Brexit has not been removed,”
# (16432004385153140588, 771, 789) “Whether we still make them is what matters in terms of the most immediate effect.”
# (16432004385153140588, 840, 858) “And those preferential trade arrangements will be lost if we exit Europe without a deal,”
# (16432004385153140588, 888, 893) “project fear.”
#
#
# 5c1efb3d1e67d78e279bd39a.txt
# 0
#
#
# 5c3436991e67d78e27d30c2c.txt
# 6
# (16432004385153140588, 460, 480) “I walked into the store because I needed cards for school and I met this sassy woman,”
# (16432004385153140588, 598, 616) “One day I changed the cake recipe and got fired for ‘creative insubordination,’”
# (16432004385153140588, 761, 790) “I was introduced to someone who worked in the test kitchen of Food And Wine magazine and was asked to write a proposal for a column,”
# (16432004385153140588, 991, 1006) “They were all chefs and I made them accessible for home cooks,”
# (16432004385153140588, 1009, 1016) “I loved doing that.”
# (16432004385153140588, 1077, 1100) “I love doing this work and I never stop thinking how lucky I am to be able to do it,”
#
#
# 5c3fefc41e67d78e270257d3.txt
# 8
# (16432004385153140588, 185, 199) "The security operation ... is over and all the terrorists eliminated,"
# (16432004385153140588, 638, 656) "Then we saw two of the attackers firing at the elevators and we turned back,"
# (16432004385153140588, 655, 664) " he told Reuters outside the hotel. "
# (16432004385153140588, 638, 664) "Then we saw two of the attackers firing at the elevators and we turned back," he told Reuters outside the hotel. "
# (16432004385153140588, 852, 857) "like snipers,"
# (16432004385153140588, 996, 1001) "shocked and saddened"
# (16432004385153140588, 1000, 1014) " to confirm the death of Luke Potter, and that he had "
# (16432004385153140588, 1268, 1278) "He is gone, he is gone,"
#
#
# 5c286d031e67d78e27b3f17b.txt
# 1
# (16432004385153140588, 186, 193) “We may never know,”
#
#
# 5c33a8ee1e67d78e27d186d1.txt
# 1
# (16432004385153140588, 355, 360) “on a train”
#
#
# 5c344a9f1e67d78e27d34d0a.txt
# 7
# (16432004385153140588, 29, 52) “With the cancellation of the public information sessions, this rally now becomes the only voice for the people locally,”
# (16432004385153140588, 269, 295) “where Albertans from Drayton Valley and Red Deer will have the opportunity to engage government officials directly with their questions about the proposal.”
# (16432004385153140588, 308, 315) “The process is flawed,”
# (16432004385153140588, 577, 618) “ongoing emails, Facebook communications and personal contacts with literally hundreds of residents of our area of West Central Alberta telling us that they have not been part of the process in the consultations on the Bighorn proposals.”
# (16432004385153140588, 730, 761) “flawed and in rural internet service areas it is both time consuming and hundreds have reported giving up due to repeatedly kicked out of the online survey process.”
# (16432004385153140588, 803, 830) “We have to start dialing back on some of the land uses if we want to maintain some of those vital resources like water,”
# (16432004385153140588, 920, 925) “inflamed rhetoric.”
#
#
# 5c48111c1e67d78e271b6146.txt
# 2
# (16432004385153140588, 391, 397) “one giant assumption.”
# (16432004385153140588, 550, 562) “it seemed to be anything but a flat intersection.”
#
#
# 5c201b371e67d78e279e248a.txt
# 1
# (16432004385153140588, 608, 612) “production hell”
#
#
# 5c547bf71e67d78e2742971d.txt
# 3
# (16432004385153140588, 193, 198) " Howell said. "
# (16432004385153140588, 197, 210) "Even trustees have noticed that smell when they walk in."
# (16432004385153140588, 193, 210) " Howell said. "Even trustees have noticed that smell when they walk in."
#
#
# 5c42296c1e67d78e270996a7.txt
# 2
# (16432004385153140588, 360, 371) “It means X is attracted to many genders.”
# (16432004385153140588, 591, 610) “How is that even possible? When I was your age there were only two genders.”
#
#
# 5c3fbf491e67d78e27f767d8.txt
# 0
#
#
# 5c546d281e67d78e27426e82.txt
# 4
# (16432004385153140588, 185, 189) "working closely"
# (16432004385153140588, 215, 220) "may not work"
# (16432004385153140588, 282, 296) "in the process of getting our internal apps up and running."
# (16432004385153140588, 575, 579) "Screenwise Meter"
#
#
# 5c2ae5f11e67d78e27ba36d7.txt
# 3
# (16432004385153140588, 311, 320) "long ways from making a decision,"
# (16432004385153140588, 636, 641) " he said. "
# (16432004385153140588, 980, 989) "the loneliest moment of my life."
#
#
# 5c182ac01e67d78e27794487.txt
# 0
#
#
# 5c29beda1e67d78e27b74939.txt
# 5
# (16432004385153140588, 128, 146) “The Australian Government is concerned about the recent detention of two Canadian citizens in China,”
# (16432004385153140588, 265, 269) “basically kidnapping”
# (16432004385153140588, 514, 518) “deep concern”
# (16432004385153140588, 566, 585) “the declared motive for their investigation raises concerns about legitimate research and business practices in China.”
# (16432004385153140588, 587, 623) “The denial of access to a lawyer under their status of detention is contrary to the right of defence. The EU fully supports the efforts of the Canadian Government on this matter.”
#
#
# 5c4888ac1e67d78e271d2cdf.txt
# 8
# (16432004385153140588, 47, 55) "They made him our problem,"
# (16432004385153140588, 191, 197) "face many more years"
# (16432004385153140588, 677, 691) "realistic prospect of controlling the threat of dangerousness and managing the risk"
# (16432004385153140588, 715, 733) "likely result in death, severe physical injury or psychological damage to a future victim."
# (16432004385153140588, 740, 746) "lacking a conscience."
# (16432004385153140588, 927, 952) "I can tell you that as with all Parole Board of Canada decisions, the protection of society is the paramount consideration,"
# (16432004385153140588, 1111, 1117) "hope than reason."
# (16432004385153140588, 1188, 1213) "We have to re-do in New York State what Paul Carver did in an attempt to have him civilly confined,"
#
#
# 5c5d532a795bd2d5c282a094.txt
# 6
# (16432004385153140588, 95, 99) “risk mitigation”
# (16432004385153140588, 506, 512) “significant upside potential.”
# (16432004385153140588, 744, 763) “We are obligated to respect the confidentiality of our policy holders and their policies with us,”
# (16432004385153140588, 948, 952) “risk mitigation”
# (16432004385153140588, 979, 1007) “EDC had the largest political risk insurance claim charge in its history as a result of the turmoil in North Africa and the Middle East,”
# (16432004385153140588, 1622, 1643) “but there have been other cases where awards have been paid out for hundreds of millions of dollars.”
#
#
# 5c384d731e67d78e27e057e9.txt
# 0
#
#
# 5c531ba91e67d78e273e272a.txt
# 5
# (16432004385153140588, 300, 308) "The situation calls for patience,"
# (16432004385153140588, 307, 318) " Chairman Jerome Powell said at a news conference. "
# (16432004385153140588, 300, 318) "The situation calls for patience," Chairman Jerome Powell said at a news conference. "
# (16432004385153140588, 317, 327) "We have the luxury to be patient."
# (16432004385153140588, 307, 327) " Chairman Jerome Powell said at a news conference. "We have the luxury to be patient."
#
#
# 5c158f201e67d78e27721ffd.txt
# 1
# (16432004385153140588, 658, 673) “I wanted to heal a little bit before I talked to him,”
#
#
# 5c3eac6f1e67d78e27f3dc55.txt
# 18
# (16432004385153140588, 102, 106) "strong dissatisfaction"
# (16432004385153140588, 184, 189) " Freeland said. "
# (16432004385153140588, 188, 216) "We believe it is inhumane and inappropriate, and wherever the death penalty is considered with regard to a Canadian we speak out against it."
# (16432004385153140588, 237, 243) "a very emotional conversation"
# (16432004385153140588, 340, 372) "Canadians who travel to countries where the death penalty is part of the criminal justice system need to be aware that it exists. That is just a reality."
# (16432004385153140588, 384, 388) "acting arbitrarily"
# (16432004385153140588, 459, 466) "our strong dissatisfaction with this"
# (16432004385153140588, 495, 499) "arbitrarily detained"
# (16432004385153140588, 527, 540) "fully assess the risks of going to Canada for tourism."
# (16432004385153140588, 558, 567) "risk of arbitrary enforcement of local laws"
#
#
# 5c2afc011e67d78e27ba73a9.txt
# 23
# (16432004385153140588, 335, 343) “Alexa, open Animal Workout.”
# (16432004385153140588, 414, 421) “Alexa, start Chompers.”
# (16432004385153140588, 547, 555) “Alexa, open Sesame Street.”
# (16432004385153140588, 704, 715) “How does your body feel when you focus?”
# (16432004385153140588, 731, 741) “Alexa, ask Focus Game to start.”
# (16432004385153140588, 795, 803) “Alexa, play Kids Quiz!”
# (16432004385153140588, 867, 875) “Alexa, open Kiwi Monsters!”
# (16432004385153140588, 952, 960) “Alexa, open Lemonade Stand.”
# (16432004385153140588, 1062, 1071) “Alexa, open The Magic Door.”
# (16432004385153140588, 1100, 1107) “Wow in the World,”
#
#
# 5c332342795bd2799e61e1ab.txt
# 0
#
#
# 5c2505451e67d78e27aac464.txt
# 0
#
#
# 5c34c2311e67d78e27d50d44.txt
# 6
# (16432004385153140588, 427, 446) "Obviously the best way to protect oneself is to be informed and to know your rights,"
# (16432004385153140588, 445, 450) " he said. "
# (16432004385153140588, 427, 450) "Obviously the best way to protect oneself is to be informed and to know your rights," he said. "
# (16432004385153140588, 797, 825) "Governments could also help the property owners by waiving certain fees and requirements to allow the owners to do repairs and renovations at lower costs,"
# (16432004385153140588, 1113, 1140) "Right now, the added motivation for a landlord is to be able to hike the rent once they get rid of the tenant."
# (16432004385153140588, 1161, 1166) "working in tandem"
#
#
# 5c3b91e91e67d78e27eaa13a.txt
# 0
#
#
# 5c2a3d191e67d78e27b8ac72.txt
# 56
# (16432004385153140588, 138, 142) "no collusion"
# (16432004385153140588, 138, 144) "no collusion" and "
# (16432004385153140588, 141, 146) " and "collusion"
# (16432004385153140588, 158, 162) "wheelhouse and "
# (16432004385153140588, 161, 166) "in the books"
# (16432004385153140588, 158, 166) "wheelhouse and "in the books"
# (16432004385153140588, 207, 221) "I can usually read a political nomination when I see it,"
# (16432004385153140588, 220, 225) " he said. "
# (16432004385153140588, 207, 225) "I can usually read a political nomination when I see it," he said. "
# (16432004385153140588, 224, 249) "If I saw a string of trolls trying to pack the ballot box for political reasons, I would have caught it."
#
#
# 5c53fcb21e67d78e2740a299.txt
# 3
# (16432004385153140588, 260, 270) "We Believe: The Best Men Can Be"
# (16432004385153140588, 434, 438) “strong man”
# (16432004385153140588, 495, 501) “boys will be boys”
#
#
# 5c3daf32795bd2eb3f0108d8.txt
# 0
#
#
# 5c20ae45795bd2d89328853e.txt
# 2
# (16432004385153140588, 211, 217) “Ring of Fire,”
# (16432004385153140588, 939, 952) “would stop at the first sign of possible high tides.”
#
#
# 5c5d15151e67d78e275d5d0f.txt
# 6
# (16432004385153140588, 68, 80) “Hey, do you ever kiss your husband anymore?”
# (16432004385153140588, 283, 311) “The craze of the big, burly lumberjack beard seems to have died off a bit in major metropolitan cities like New York or Toronto,”
# (16432004385153140588, 512, 526) “One of the most attractive things in a relationship is confidence,”
# (16432004385153140588, 529, 553) “And although we may want our partner to do something we like, we also want them to feel like themselves.”
# (16432004385153140588, 734, 741) “Then just scale back!”
# (16432004385153140588, 1048, 1057) “It can be a little degrading,”
#
#
# 5c4977bc1e67d78e27204091.txt
# 1
# (16432004385153140588, 29, 35) “quite a strong case”
#
#
# 5c4a89f31e67d78e27233c5d.txt
# 5
# (16432004385153140588, 72, 90) "I came all the way from Syria, and I came here to thank you,"
# (16432004385153140588, 206, 224) "Welcoming people who are trying to build a better life is what built this country,"
# (16432004385153140588, 707, 719) "Obviously the Francophonie Games are deeply important to me,"
# (16432004385153140588, 718, 723) " Trudeau said. "
# (16432004385153140588, 707, 723) "Obviously the Francophonie Games are deeply important to me," Trudeau said. "
#
#
# 5c3533311e67d78e27d653f4.txt
# 9
# (16432004385153140588, 132, 150) “I would say it was beyond what we would consider an acceptable make-good,”
# (16432004385153140588, 164, 176) “To do what he did … was just terrific.”
# (16432004385153140588, 349, 360) “Winning was going to put me in default,”
# (16432004385153140588, 472, 487) “I want to give something back so I can fulfill an obligation.”
# (16432004385153140588, 511, 515) “major penalty”
# (16432004385153140588, 615, 623) “That would tick two boxes,”
# (16432004385153140588, 683, 691) “We had a great time,”
# (16432004385153140588, 777, 781) “petro heads”
# (16432004385153140588, 939, 953) “The report we got back was it was an exceptional day,”
#
#
# 5c284a201e67d78e27b38e6e.txt
# 3
# (16432004385153140588, 140, 156) “My eyes are full of tears because I love this land so deeply,”
# (16432004385153140588, 570, 584) “Essentially, the leader will choose the candidate in each byelection,”
# (16432004385153140588, 613, 617) “whole country”
#
#
# 5c2060d31e67d78e279eb852.txt
# 1
# (16432004385153140588, 495, 506) “There are a lot of real concerns here.”
#
#
# 5c287b841e67d78e27b4163e.txt
# 4
# (16432004385153140588, 256, 272) "You can see his impact on our team with the players around him,"
# (16432004385153140588, 271, 282) " DeBoer said of the former Ottawa Senators captain. "
# (16432004385153140588, 256, 282) "You can see his impact on our team with the players around him," DeBoer said of the former Ottawa Senators captain. "
# (16432004385153140588, 773, 791) " said the rookie defenceman, younger brother of Seth Jones of the Columbus Blue Jackets. "
#
#
# 5c5555d11e67d78e27457a93.txt
# 0
#
#
# 5c5d37341e67d78e275dc30f.txt
# 4
# (16432004385153140588, 137, 142) " VanVleet said. "
# (16432004385153140588, 473, 480) "Frustration, anger and helplessness"
# (16432004385153140588, 479, 485) " on Twitter, writing "
# (16432004385153140588, 697, 702) " said Powell. "
#
#
# 5c1efb3f1e67d78e279bd3b4.txt
# 3
# (16432004385153140588, 163, 168) "Accordion Man."
# (16432004385153140588, 543, 555) "You know, they might throw tomatoes at you!"
# (16432004385153140588, 1057, 1064) "Maybe we started something,"
#
#
# 5c3ed6b11e67d78e27f46477.txt
# 3
# (16432004385153140588, 91, 102) “The ambulance station was literally seven minutes away.”
# (16432004385153140588, 590, 624) “The emergency department cares for the sickest individual first, which at times could result in less acute individuals waiting and they could be an individual in an ambulance brought in.”
# (16432004385153140588, 722, 743) “The long hours are happening because ambulances are pulled in to places where there are no available ambulances,”
#
#
# 5c53eea41e67d78e27407cc3.txt
# 1
# (16432004385153140588, 456, 466) “giving the best care under the circumstances,”
#
#
# 5c5d292b1e67d78e275d9e9f.txt
# 4
# (16432004385153140588, 39, 48) “The fear will not go away,”
# (16432004385153140588, 51, 58) “This can happen again.”
# (16432004385153140588, 607, 616) “But then it disappeared rapidly afterwards,”
# (16432004385153140588, 670, 681) “I am looking forward to see the sentence,”
#
#
# 5c34c92a1e67d78e27d52117.txt
# 10
# (16432004385153140588, 159, 181) "I was excited to have some time off, but I was excited to get right back to it,"
# (16432004385153140588, 180, 189) " Hadwin said by phone from Phoenix. "
# (16432004385153140588, 188, 200) "Hopefully that translates into another quick start this year."
# (16432004385153140588, 180, 200) " Hadwin said by phone from Phoenix. "Hopefully that translates into another quick start this year."
# (16432004385153140588, 282, 301) "I definitely lost in putting, and that was plainly obvious as the year went on,"
# (16432004385153140588, 300, 305) " he said. "
# (16432004385153140588, 501, 506) " Hadwin said. "
# (16432004385153140588, 1090, 1094) "little sore"
# (16432004385153140588, 1093, 1101) " after hitting balls last week but "
# (16432004385153140588, 1090, 1101) "little sore" after hitting balls last week but "
#
#
# 5c25054e1e67d78e27aac4ef.txt
# 10
# (16432004385153140588, 57, 73) " Brooks said while sitting in a church near Yonge Street and Eglinton Avenue. "
# (16432004385153140588, 72, 89) "People have been beaten and beaten and beaten all our lives, like myself."
# (16432004385153140588, 171, 180) "Where do you draw the line?"
# (16432004385153140588, 240, 253) "I was asked how can I help the next guy,"
# (16432004385153140588, 252, 257) " Brooks says. "
# (16432004385153140588, 240, 257) "I was asked how can I help the next guy," Brooks says. "
# (16432004385153140588, 1345, 1383) "We saw this as an opportunity to use technology to help individuals during a difficult time of year, and support our partners as they strive to find innovative solutions that create a better Toronto,"
# (16432004385153140588, 1755, 1759) "the boys"
# (16432004385153140588, 1755, 1766) "the boys"— who live in tents. "
# (16432004385153140588, 1765, 1776) "I got presents for every one of them,"
#
#
# 5c3e038e1e67d78e27f2105a.txt
# 4
# (16432004385153140588, 184, 194) " Barron County District Attorney Brian Wright said. "
# (16432004385153140588, 438, 444) "expectations and standards,"
# (16432004385153140588, 495, 506) "was the girl he was going to take."
# (16432004385153140588, 1073, 1079) "bad things would happen"
#
#
# 5c1452701e67d78e276ee126.txt
# 5
# (16432004385153140588, 1516, 1548) “When the books were shown to me, I was deeply dismayed and shaken to the core to see how much debt the City of Surrey has been carrying,”
# (16432004385153140588, 1625, 1629) “previously approved”
# (16432004385153140588, 1706, 1710) “previously approved”
# (16432004385153140588, 2727, 2738) “That graph should go in the other direction.”
# (16432004385153140588, 2769, 2787) “We could not supply one sheet of ice for them for any games all year,”
#
#
# 5c3e11b11e67d78e27f2357a.txt
# 8
# (16432004385153140588, 147, 164) "to date, we have not yet identified any issues regarding police officer conduct."
# (16432004385153140588, 250, 256) "chaos all around."
# (16432004385153140588, 757, 785) "the level of trust between the RCMP and the Hereditary Chiefs now in place will continue to play a direct and positive role going forward."
# (16432004385153140588, 800, 811) "I believe there has to be trust built."
# (16432004385153140588, 810, 815) " he said. "
# (16432004385153140588, 800, 815) "I believe there has to be trust built." he said. "
# (16432004385153140588, 814, 830) "This is too fresh in our minds, too fresh in our souls."
# (16432004385153140588, 867, 881) "significantly scaled down presence, one that everyone is comfortable with."
#
#
# 5c3f00a6795bd298e67a078f.txt
# 7
# (16432004385153140588, 226, 234) “what the House does support.”
# (16432004385153140588, 360, 369) “a catastrophic defeat for this government,”
# (16432004385153140588, 537, 554) “With people knowing what it is that they are actually voting for this time.”
# (16432004385153140588, 628, 639) “I think no deal is the only deal.”
# (16432004385153140588, 708, 718) “The path forward is far from clear,”
# (16432004385153140588, 852, 868) “to clarify its intentions with respect to next steps as soon as possible.”
# (16432004385153140588, 1118, 1136) “hoping that desperation and panic may bring more MPs on all sides into her camp.”
#
#
# 5c3d854a1e67d78e27f049d6.txt
# 0
#
#
# 5c1f328f1e67d78e279c7d31.txt
# 11
# (16432004385153140588, 250, 256) “Trudeau must go!”
# (16432004385153140588, 258, 268) “Our energy allies are laughing at us,”
# (16432004385153140588, 354, 360) “Quebec please separate,”
# (16432004385153140588, 360, 364) “Build pipelines”
# (16432004385153140588, 354, 364) “Quebec please separate,” “Build pipelines”
# (16432004385153140588, 365, 373) “The UN is a scam,”
# (16432004385153140588, 412, 417) “global takeover.”
# (16432004385153140588, 474, 489) “reaffirms the sovereign right of states to determine their national migration policy.”
# (16432004385153140588, 546, 561) “I feel like this is overarching — more law than we need,”
# (16432004385153140588, 981, 987) “all shapes and sizes”
#
#
# 5c2a60611e67d78e27b8feef.txt
# 3
# (16432004385153140588, 697, 703) “Face the Nation.”
# (16432004385153140588, 1295, 1309) “Our goal is to make sure we move on our promises,”
# (16432004385153140588, 1317, 1324) “tremendous influence on what happens”
#
#
# 5c4a4b361e67d78e27229cbe.txt
# 0
#
#
# 5c28972a795bd2fac69fa974.txt
# 3
# (16432004385153140588, 128, 144) “My eyes are full of tears because I love this land so deeply,”
# (16432004385153140588, 576, 590) “Essentially, the leader will choose the candidate in each byelection,”
# (16432004385153140588, 619, 623) “whole country”
#
#
# 5c2994741e67d78e27b6d2ff.txt
# 3
# (16432004385153140588, 126, 142) "My eyes are full of tears because I love this land so deeply,"
# (16432004385153140588, 602, 616) "Essentially, the leader will choose the candidate in each byelection,"
# (16432004385153140588, 645, 649) "whole country"
#
#
# 5c3474bf795bd22cf586482c.txt
# 0
#
#
# 5c44cc6a1e67d78e2711813d.txt
# 5
# (16432004385153140588, 406, 421) "He was certain I could play anything I set my mind to."
# (16432004385153140588, 774, 781) “three-string rock,”
# (16432004385153140588, 863, 875) “I figured out the theme song to The Simpsons!”
# (16432004385153140588, 885, 904) "It turns out you can progress a lot even on five minutes of practice a day."
# (16432004385153140588, 1380, 1387) “four-string rock.”
#
#
# 5c15488f1e67d78e277161d7.txt
# 3
# (16432004385153140588, 128, 137) “pay up and pollute all you want”
# (16432004385153140588, 460, 470) “While Conservatives fiddle, the planet burns!”
# (16432004385153140588, 481, 485) “goal post”
#
#
# 5c3f4e281e67d78e27f62b50.txt
# 7
# (16432004385153140588, 814, 827) "The real question is do we want more Audrey Parkers?"
# (16432004385153140588, 826, 831) " said Gokool. "
# (16432004385153140588, 814, 831) "The real question is do we want more Audrey Parkers?" said Gokool. "
# (16432004385153140588, 882, 891) "in an advanced stage of irreversible decline"
# (16432004385153140588, 890, 908) " from a serious and incurable disease, illness or disability and for whom natural death is "
# (16432004385153140588, 907, 912) "reasonably foreseeable."
# (16432004385153140588, 935, 940) "grievous and irremediable"
#
#
# 5c3474c2795bd22cf5864830.txt
# 9
# (16432004385153140588, 67, 72) “amazed and overwhelmed”
# (16432004385153140588, 111, 119) “Help us help our coach,”
# (16432004385153140588, 164, 171) “Coach Stephen is really sick”
# (16432004385153140588, 172, 184) “We need to find a donor for Coach Stephen.”
# (16432004385153140588, 276, 281) “a bit weird”
# (16432004385153140588, 438, 442) “selfie video”
# (16432004385153140588, 444, 450) “not too sad.”
# (16432004385153140588, 629, 638) “Please help us help our coach,”
# (16432004385153140588, 698, 719) “He was just trying to make himself better as a coach and us better as people and players.”
#
#
# 5c489df91e67d78e271d66c5.txt
# 3
# (16432004385153140588, 331, 351) "He enabled us to at least hang in there and get a point out of this game,"
# (16432004385153140588, 358, 385) "The positive is you came in here against one of the best teams and in my opinion, we could have had that game."
# (16432004385153140588, 706, 711) " Peters said. "
#
#
# 5c3377b81e67d78e27d10a65.txt
# 4
# (16432004385153140588, 149, 171) "For people of working age, one of the most important things is the ability to work and earn,"
# (16432004385153140588, 317, 353) "Three years after admission to hospital for any of these health events, people who survived were less likely than the matched participants to be working and had greater losses in annual earnings,"
# (16432004385153140588, 678, 683) " she said. "
# (16432004385153140588, 1020, 1054) "I think that the goal here needs to be to understand the magnitude of these problems ... and then institute policies to try to help these people get back to work."
#
#
# 5c3eec791e67d78e27f51065.txt
# 6
# (16432004385153140588, 65, 70) “Bam Bam.”
# (16432004385153140588, 72, 78) “Are there prizes?”
# (16432004385153140588, 88, 101) “If I throw my back out, are there prizes?”
# (16432004385153140588, 200, 208) “let the wind play through,”
# (16432004385153140588, 221, 231) “Into the wind is not my specialty,”
# (16432004385153140588, 356, 376) “I feel like events like this are really going to help us get more eyeballs on us,”
#
#
# 5c1f1d831e67d78e279c35b4.txt
# 17
# (16432004385153140588, 220, 225) “very exciting,”
# (16432004385153140588, 389, 394) “high-normal”
# (16432004385153140588, 463, 468) “normal-high”
# (16432004385153140588, 783, 789) “small, healthy choices”
# (16432004385153140588, 812, 818) “and two belt loops”
# (16432004385153140588, 830, 849) “I always had good intentions about exercising. But this helped me get with the program,”
# (16432004385153140588, 906, 917) “My blood pressure is down to normal now,”
# (16432004385153140588, 941, 960) “I had a health club membership, but this program really helped me develop a habit,”
# (16432004385153140588, 999, 1007) “was a real eye-opener”
# (16432004385153140588, 1010, 1017) “No more white bread,”
#
#
# 5c1df61f1e67d78e2798f3fe.txt
# 0

# %%
# load a text file. Remember, you have to do 5
with open ("A1_data/5c1dbe1d1e67d78e2797d611.txt", "r", encoding='utf-8') as f:
    text = f.read()

# %%
print(os.getcwd())
# Out:
# /home/a1a01287-00fd-4f66-9d41-05fe0b880957/LING807 Compuling

# %%
# combination of different OP. 

matcher = Matcher(nlp.vocab)
pattern_q = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "!"}, {'IS_PUNCT': True, "OP": "!"}, {'ORTH': '"'}] #0
pattern_q1 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "!"}, {'IS_PUNCT': True, "OP": "?"}, {'ORTH': '"'}] #0
pattern_q2 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "!"}, {'IS_PUNCT': True, "OP": "+"}, {'ORTH': '"'}] #0
pattern_q3 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "!"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #0

pattern_q4 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "?"}, {'IS_PUNCT': True, "OP": "!"}, {'ORTH': '"'}] #0
pattern_q5 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "?"}, {'IS_PUNCT': True, "OP": "?"}, {'ORTH': '"'}] #0
pattern_q6 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "?"}, {'IS_PUNCT': True, "OP": "+"}, {'ORTH': '"'}] #0
pattern_q7 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "?"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #0

pattern_q8 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "!"}, {'ORTH': '"'}] #0
pattern_q9 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "?"}, {'ORTH': '"'}] #3
pattern_q10 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "+"}, {'ORTH': '"'}] #3
pattern_q11 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #3

pattern_q12 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'IS_PUNCT': True, "OP": "!"}, {'ORTH': '"'}] #0
pattern_q13 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'IS_PUNCT': True, "OP": "?"}, {'ORTH': '"'}] #3
pattern_q14 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'IS_PUNCT': True, "OP": "+"}, {'ORTH': '"'}] #3
pattern_q15 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #3

pattern_q16 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '"'}] #7
pattern_q17 = [{'ORTH': '“'}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'IS_ALPHA': True, "OP": "+"}, {'IS_PUNCT': True, "OP": "*"}, {'ORTH': '”'}] #4

#pattern_q4 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "+"}, {'ORTH': '"'}]  #control
#pattern_q5 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'ORTH': '.,!?': True, "OP": "+"}, {'ORTH': '"'}] 
#pattern_q6 = [{'ORTH': '"'}, {'IS_ALPHA': True, "OP": "*"}, {'ORTH': '"'}]
#pattern_q7 = [{'ORTH': '"'}, {'IS_ALPHA': True, 'OP': '?'}, {'ORTH': '"'}]

matcher.add("QUOTES", [pattern_q16, pattern_q17])
doc = nlp(text)
matches_q = matcher(doc)
# matches_q.sort(key = lambda x: x[1])
print (len(matches_q))
for match in matches_q[:10]:
    print (match, doc[match[1]:match[2]])

# MAYBE STRAIGHT/CURLY QUOTATION MARKS MATTER, SINCE IT IS RECOGNISING THE MIDDLE PART OF THE QUOTES AS WELL
# Out:
# 7
# (16432004385153140588, 108, 116) " Kim told CTV News Friday. "
# (16432004385153140588, 115, 133) "The fact that we are being accused right now of an unethical adoption is crazy."
# (16432004385153140588, 108, 133) " Kim told CTV News Friday. "The fact that we are being accused right now of an unethical adoption is crazy."
# (16432004385153140588, 164, 174) "It does say that in the letter,"
# (16432004385153140588, 173, 180) " Kim confirmed, adding that "
# (16432004385153140588, 179, 209) "I have no idea where that information came from because both Clark and I were there in the office with all of the workers from the orphanage."
# (16432004385153140588, 280, 309) "in some cases, extra steps in the citizenship or immigration process may be needed to make sure the adoption meets all requirements of international adoption."

# %% [markdown]
# ## Approach 3: Implemented version
# This approach was implemented by colleagues at the [Australian Text Analytics Platform](https://www.atap.edu.au/) (ATAP). The approach is based on the [Gender Gap Tracker](https://github.com/sfu-discourse-lab/GenderGapTracker) done in the Discourse Processing Lab here at SFU.
#
# The first link below leads you to a binder where you can load your own files and download the output. If you prefer to do everything in your own notebook, you can download/clone the project from GitHub.
#
# * [Binder link](https://github.com/Australian-Text-Analytics-Platform/quotation-tool/blob/workshop_01_20220908/README.md)
#
#     * Click on the "binder launch" button.
#     * At the CILogin, under "Select an Identity Provider", go to the drop-down menu (usually default as ORCID) and select "Simon Fraser University".
#     * This launches [Binder](https://mybinder.readthedocs.io/en/latest/), a service that allows you to run a notebook online on Jupyter Lab (similar to Google Colab).
#     * Run all the code cells in that notebook, uploading files from the A1_data directory.
#     * At the end, you can save the output as an Excel file.
#
# * [Regular GitHub project](https://github.com/Australian-Text-Analytics-Platform/quotation-tool)
#
#     * Run the notebook "quote_extractor_notebook.ipynb"
#
# Within the ATAP binder, upload 5 files from A1_data (the same you did for approaches 1 and 2), process them and download the results to your own computer.

# %% [markdown]
# ## Your turn
#
# Check instructions on Canvas for what to do and what to submit.
